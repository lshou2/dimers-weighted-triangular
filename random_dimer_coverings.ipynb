# %%
from random_sample_triangular import *

# %% [markdown]
# Note: As described in the code, this is very inefficient, but it can generate a few small random samples.

# %% [markdown]
# ## Double-dimer coverings, rectangular/smaller size

# %%
# %time r82_1 = random_covering(82, gen_rectangle_bool(.75), weights=[1,1,1,1,1,1])
# %time r82_2 = random_covering(82, gen_rectangle_bool(.75), weights=[1,1,1,1,1,1])
# Out:
# CPU times: user 18.2 s, sys: 42.5 ms, total: 18.3 s
# Wall time: 18.3 s
# CPU times: user 18.6 s, sys: 300 ms, total: 18.9 s
# Wall time: 18.9 s

# %%
plot_2covers(82, gen_rectangle_bool(.75), r82_1, r82_2, axes=False, savename='double_dimer_a1_n82_75.pdf',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time r82_a3_1 = random_covering(82, gen_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# %time r82_a3_2 = random_covering(82, gen_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 19.6 s, sys: 164 ms, total: 19.8 s
# Wall time: 19.6 s
# CPU times: user 19.7 s, sys: 80.2 ms, total: 19.8 s
# Wall time: 19.8 s

# %%
# %time r82_a3_3 = random_covering(82, gen_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# %time r82_a3_4 = random_covering(82, gen_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 20 s, sys: 176 ms, total: 20.1 s
# Wall time: 20.1 s
# CPU times: user 20 s, sys: 176 ms, total: 20.2 s
# Wall time: 20.2 s

# %%
plot_2covers(82, gen_rectangle_bool(.75), r82_a3_2, r82_a3_4, axes=False, savename='double_dimer_a3_n82_75.pdf',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time r82_a5_1 = random_covering(82, gen_rectangle_bool(.75), weights=[5,1,1,1,1,1])
# %time r82_a5_2 = random_covering(82, gen_rectangle_bool(.75), weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 19.9 s, sys: 536 ms, total: 20.4 s
# Wall time: 20.3 s
# CPU times: user 19.9 s, sys: 556 ms, total: 20.5 s
# Wall time: 20.5 s

# %%
plot_2covers(82, gen_rectangle_bool(.75), r82_a5_1, r82_a5_2, axes=False, savename='double_dimer_a5_n82_75.pdf',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %% [markdown]
# ## Double-dimer coverings

# %%
# %time c82_1 = random_covering(82, square_bool, weights=[1,1,1,1,1,1])
# %time c82_2 = random_covering(82, square_bool, weights=[1,1,1,1,1,1])
# Out:
# CPU times: user 1min 1s, sys: 2min 3s, total: 3min 5s
# Wall time: 40 s
# CPU times: user 1min 2s, sys: 2min 4s, total: 3min 6s
# Wall time: 40.2 s

# %%
plot_2covers(82, square_bool, c82_1, c82_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time c82_a3_1 = random_covering(82, square_bool, weights=[3,1,1,1,1,1])
# %time c82_a3_2 = random_covering(82, square_bool, weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 1min 7s, sys: 2min 14s, total: 3min 21s
# Wall time: 43.3 s
# CPU times: user 1min 13s, sys: 2min 32s, total: 3min 46s
# Wall time: 47.6 s

# %%
plot_2covers(82, square_bool, c82_a3_1, c82_a3_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time c82_a5_1 = random_covering(82, square_bool, weights=[5,1,1,1,1,1])
# %time c82_a5_2 = random_covering(82, square_bool, weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 1min 10s, sys: 2min 27s, total: 3min 37s
# Wall time: 44.5 s
# CPU times: user 1min 8s, sys: 2min 16s, total: 3min 25s
# Wall time: 43.6 s

# %%
plot_2covers(82, square_bool, c82_a5_1, c82_a5_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %% [markdown]
# ## Single dimer cover

# %%
# %time plot_cover(50,square_bool,random_covering(50, square_bool, weights=[1,1,1,1,1,1]))
# Out:
# CPU times: user 4.6 s, sys: 21.2 ms, total: 4.63 s
# Wall time: 4.6 s
# 0

# %%
plot_cover(82, square_bool, c82_1, axes=False)
# Out:
# 0

# %%
plot_cover(82, square_bool, c82_a3_1, axes=False)
# Out:
# 0

# %%
plot_cover(82, square_bool, c82_a5_1, axes=False)
# Out:
# 0

# %% [markdown]
# ## Aztec diamond

# %%
# %time a82_1 = random_covering(82, aztec_bool, weights=[1,1,1,1,1,1])
# %time a82_2 = random_covering(82, aztec_bool, weights=[1,1,1,1,1,1])
# Out:
# /usr/lib/python3/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:394: SparseEfficiencyWarning: splu converted its input to CSC format
#   warn('splu converted its input to CSC format', SparseEfficiencyWarning)
# CPU times: user 8.41 s, sys: 24.9 ms, total: 8.44 s
# Wall time: 8.44 s
# CPU times: user 8.55 s, sys: 27.7 ms, total: 8.58 s
# Wall time: 8.58 s

# %%
plot_2covers(82, aztec_bool, a82_1, a82_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time a82_a3_1 = random_covering(82, aztec_bool, weights=[3,1,1,1,1,1])
# %time a82_a3_2 = random_covering(82, aztec_bool, weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 9.26 s, sys: 156 ms, total: 9.41 s
# Wall time: 9.3 s
# CPU times: user 9.35 s, sys: 208 ms, total: 9.56 s
# Wall time: 9.56 s

# %%
plot_2covers(82, aztec_bool, a82_a3_1, a82_a3_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0

# %%
# %time a82_a5_1 = random_covering(82, aztec_bool, weights=[5,1,1,1,1,1])
# %time a82_a5_2 = random_covering(82, aztec_bool, weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 9.29 s, sys: 372 ms, total: 9.66 s
# Wall time: 9.52 s
# CPU times: user 9.13 s, sys: 244 ms, total: 9.38 s
# Wall time: 9.38 s

# %%
plot_2covers(82, aztec_bool, a82_a5_1, a82_a5_2, axes=False, savename='',\
                 loopcolor='k', decolor='darkgrey', dewidth=.5)
# Out:
# 0
