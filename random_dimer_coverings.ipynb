# %%
from random_sample_triangular import *

# %% [markdown]
# Note: As described in the code, this is very inefficient, but it can generate a few small random samples.

# %% [markdown]
# ## Double-dimer coverings, rectangular/smaller size

# %%
# %time r82_1 = random_covering(82, make_rectangle_bool(.75), weights=[1,1,1,1,1,1])
# %time r82_2 = random_covering(82, make_rectangle_bool(.75), weights=[1,1,1,1,1,1])
# Out:
# /usr/lib/python3/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:394: SparseEfficiencyWarning: splu converted its input to CSC format
#   warn('splu converted its input to CSC format', SparseEfficiencyWarning)
# CPU times: user 18.4 s, sys: 72.3 ms, total: 18.5 s
# Wall time: 18.5 s
# CPU times: user 18.4 s, sys: 65.2 ms, total: 18.4 s
# Wall time: 18.4 s

# %%
plot_2covers(82, make_rectangle_bool(.75), r82_1, r82_2, axes=False, savename='double_dimer_a1_n82_75.pdf',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time r82_a3_1 = random_covering(82, make_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# %time r82_a3_2 = random_covering(82, make_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 19.3 s, sys: 72.9 ms, total: 19.4 s
# Wall time: 19.3 s
# CPU times: user 19.5 s, sys: 216 ms, total: 19.7 s
# Wall time: 19.7 s

# %%
# %time r82_a3_3 = random_covering(82, make_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# %time r82_a3_4 = random_covering(82, make_rectangle_bool(.75), weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 19.7 s, sys: 432 ms, total: 20.2 s
# Wall time: 20.2 s
# CPU times: user 19.7 s, sys: 588 ms, total: 20.3 s
# Wall time: 20.3 s

# %%
plot_2covers(82, make_rectangle_bool(.75), r82_a3_2, r82_a3_4, axes=False, savename='double_dimer_a3_n82_75.pdf',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time r82_a5_1 = random_covering(82, make_rectangle_bool(.75), weights=[5,1,1,1,1,1])
# %time r82_a5_2 = random_covering(82, make_rectangle_bool(.75), weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 19.7 s, sys: 696 ms, total: 20.4 s
# Wall time: 20.2 s
# CPU times: user 19.5 s, sys: 36.2 ms, total: 19.6 s
# Wall time: 19.6 s

# %%
plot_2covers(82, make_rectangle_bool(.75), r82_a5_1, r82_a5_2, axes=False, savename='double_dimer_a5_n82_75.pdf',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %% [markdown]
# ## Double-dimer coverings, square size

# %%
# %time c82_1 = random_covering(82, square_bool, weights=[1,1,1,1,1,1])
# %time c82_2 = random_covering(82, square_bool, weights=[1,1,1,1,1,1])
# Out:
# CPU times: user 1min 3s, sys: 2min 19s, total: 3min 22s
# Wall time: 40.3 s
# CPU times: user 1min 1s, sys: 2min 4s, total: 3min 6s
# Wall time: 40.9 s

# %%
plot_2covers(82, square_bool, c82_1, c82_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time c82_a3_1 = random_covering(82, square_bool, weights=[3,1,1,1,1,1])
# %time c82_a3_2 = random_covering(82, square_bool, weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 1min 7s, sys: 2min 20s, total: 3min 27s
# Wall time: 44.6 s
# CPU times: user 1min 8s, sys: 2min 27s, total: 3min 36s
# Wall time: 45.3 s

# %%
plot_2covers(82, square_bool, c82_a3_1, c82_a3_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time c82_a5_1 = random_covering(82, square_bool, weights=[5,1,1,1,1,1])
# %time c82_a5_2 = random_covering(82, square_bool, weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 1min 11s, sys: 2min 35s, total: 3min 47s
# Wall time: 46.1 s
# CPU times: user 1min 14s, sys: 2min 52s, total: 4min 7s
# Wall time: 46.5 s

# %%
plot_2covers(82, square_bool, c82_a5_1, c82_a5_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %% [markdown]
# ## Single dimer cover

# %%
# %time plot_cover(50,square_bool,random_covering(50, square_bool, weights=[1,1,1,1,1,1]))
# Out:
# CPU times: user 4.68 s, sys: 127 ms, total: 4.81 s
# Wall time: 4.64 s
# 0

# %%
plot_cover(82, square_bool, c82_1, axes=False)
# Out:
# 0

# %%
plot_cover(82, square_bool, c82_a3_1, axes=False)
# Out:
# 0

# %%
plot_cover(82, square_bool, c82_a5_1, axes=False)
# Out:
# 0

# %% [markdown]
# ## Aztec diamond

# %%
# %time a82_1 = random_covering(82, aztec_bool, weights=[1,1,1,1,1,1])
# %time a82_2 = random_covering(82, aztec_bool, weights=[1,1,1,1,1,1])
# Out:
# CPU times: user 8.54 s, sys: 140 ms, total: 8.68 s
# Wall time: 8.53 s
# CPU times: user 8.68 s, sys: 4.24 ms, total: 8.69 s
# Wall time: 8.69 s

# %%
plot_2covers(82, aztec_bool, a82_1, a82_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time a82_a3_1 = random_covering(82, aztec_bool, weights=[3,1,1,1,1,1])
# %time a82_a3_2 = random_covering(82, aztec_bool, weights=[3,1,1,1,1,1])
# Out:
# CPU times: user 9.11 s, sys: 107 ms, total: 9.22 s
# Wall time: 9.08 s
# CPU times: user 9.12 s, sys: 1.16 ms, total: 9.13 s
# Wall time: 9.13 s

# %%
plot_2covers(82, aztec_bool, a82_a3_1, a82_a3_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0

# %%
# %time a82_a5_1 = random_covering(82, aztec_bool, weights=[5,1,1,1,1,1])
# %time a82_a5_2 = random_covering(82, aztec_bool, weights=[5,1,1,1,1,1])
# Out:
# CPU times: user 9.25 s, sys: 127 ms, total: 9.37 s
# Wall time: 9.23 s
# CPU times: user 9.07 s, sys: 3.6 ms, total: 9.07 s
# Wall time: 9.07 s

# %%
plot_2covers(82, aztec_bool, a82_a5_1, a82_a5_2, axes=False, savename='',\
                 loopcolor='k', double_edge_color='darkgrey', double_edge_width=.5)
# Out:
# 0
